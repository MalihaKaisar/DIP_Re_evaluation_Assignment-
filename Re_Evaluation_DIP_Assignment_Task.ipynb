# %% [markdown]
# <a href="https://colab.research.google.com/github/MalihaKaisar/DIP_Reevaluation_Assignment/blob/main/Re_Evaluation_DIP_Assignment_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task of DIP Lab Final 2024(SEC 2019-20):
# 1.  Upload the image(`DIP_Lab_task_01.png`) from drive with extracting details like: image dimension, frequency distribution of intensities, range. [5]
# 2.  Convert the RGB image(`DIP_Lab_task_02.jpg`) to a gray scale image and compare a sub-region of the image by intensity values(5*5 dimension would be enough for comparison). [10]
# 3.  Apply Image(`DIP_Lab_task_03.png`) smoothing with appropriate kernel applied. Identify the noise(if any) before processing. [35]
# 4.  Implement an appropriate technique to reduce the brightness of the provided image (`DIP_Lab_task_04.jpg`) effectively. [20]
# 5.  Solve the segmentation problem for the given image: `'DIP_Lab_task_05.jpg'` [30]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**FIRST TASK**

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np


image1 = cv2.imread('/content/drive/MyDrive/Assignment_DIP/DIP_Lab_task_01.png')
plt.imshow(image1)
plt.show()

print("")

print("Dimension Is: ")
print(np.shape(image1))
# Out:
# Dimension Is:
# (225, 225, 3)

# %%
print("Frequency Distribution: ")
histogram_distrubution = cv2.calcHist([image1],[0],None,[256],[0,256])
plt.plot(histogram_distrubution )
plt.show()

print("")

print("Range is: ")
print(image1.max() - image1.min() + 1)
# Out:
# Frequency Distribution:
# Range is:
# 251

# %% [markdown]
# #**Second Task**

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np


image2 = cv2.imread('/content/drive/MyDrive/Assignment_DIP/DIP_Lab_task_02.jpg')
plt.imshow(image2)
plt.show()

# %%
image_path = "/content/drive/MyDrive/Assignment_DIP/DIP_Lab_task_02.jpg"
image2 = cv2.imread(image_path)

gray_image = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

x, y = 50, 50
sub_region = gray_image[y:y+5, x:x+5]

plt.imshow(gray_image, cmap='gray')
plt.title("Grayscale Image")
plt.show()

print("")
print("5x5 Sub-region Intensity Values:")
print(sub_region)
print("")
plt.imshow(sub_region, cmap='gray')
plt.title("5x5 Sub-region Intensity")
plt.show()
# Out:
# 5x5 Sub-region Intensity Values:
# [[106 107 108 109 107]
#  [114 115 113 114 112]
#  [118 119 118 118 116]
#  [120 120 121 120 118]
#  [122 122 120 120 119]]

# %% [markdown]
# # **THIRD TASK**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path_3 = "/content/drive/MyDrive/Assignment_DIP/DIP_Lab_task_03.png"
image3 = cv2.imread(image_path_3)


plt.imshow(image3, cmap='gray')
plt.title("Original Image")
plt.show()


noise_detected = np.var(image3)
print(f"Noise detected in the image: {noise_detected}")

smoothed_image_3 = cv2.medianBlur(image3, 5)

plt.imshow(smoothed_image_3, cmap='gray')
plt.title("Smoothed Image")
plt.show()
# Out:
# Noise detected in the image: 2203.0229605100785

# %% [markdown]
# #**Forth Task**

# %%
image_path_4 = "/content/drive/MyDrive/Assignment_DIP/DIP_Lab_task_04.jpg"
image4 = cv2.imread(image_path_4)

hsv_image = cv2.cvtColor(image4, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv_image)


v = cv2.subtract(v, 50)
reduced_brightness = cv2.merge((h, s, v))
final_image = cv2.cvtColor(reduced_brightness, cv2.COLOR_HSV2BGR)


plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image4, cv2.COLOR_BGR2RGB))
plt.title("Original Image ")
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(final_image, cv2.COLOR_BGR2RGB))
plt.title("Brightness Reduced")
plt.show()

# %% [markdown]
# #**Fifth Task**

# %%
image_path_5 = "/content/drive/MyDrive/Assignment_DIP/DIP_Lab_task_05.jpg"

image5 = cv2.imread(image_path_5,cv2.IMREAD_GRAYSCALE)


plt.imshow(image5, cmap='gray')
plt.title("Original Image ")
plt.show()

_, segmented_image = cv2.threshold(image5, 127, 255, cv2.THRESH_BINARY)

plt.imshow(segmented_image, cmap='gray')
plt.title("Segmented Image")
plt.show()
